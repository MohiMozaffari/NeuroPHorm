# %%
import os
from pathlib import Path
import numpy as np
os.chdir(r"C:\Users\Mohad\Documents\Programming\NeuroPHorm")
import neurophorm as nf

# %%
OUTDIR = Path("examples/node_removal")

# %%
np.random.seed(42)
atlas = np.random.randint(1, 4, size=25)
atlas
# Out:
# array([3, 1, 3, 3, 1, 1, 3, 2, 3, 3, 3, 3, 1, 3, 2, 1, 2, 2, 2, 2, 1, 1,
#        2, 2, 1])

# %%
mean_df, error_df  = nf.load_removal_data(OUTDIR, atlas)
# Out:
# [INFO] 2025-09-04 18:55:23,454 - neurophorm.node_removal - load_removal_data: start | out_dir=examples\node_removal
# [INFO] 2025-09-04 18:55:23,465 - neurophorm.node_removal - load_removal_data: done | mean_df=(3, 2) | error_df=(3, 2)

# %%
nf.plot_node_removal(mean_df, error_df, ylim=(0.2,0.35))
# Out:
# [INFO] 2025-09-04 18:55:23,488 - neurophorm.visualization - plot_node_removal: start | mean=(3, 2) error=(3, 2) | save=False(pdf) | show=True
# [INFO] 2025-09-04 18:55:24,664 - neurophorm.visualization - plot_node_removal: done

# %%
nf.plot_node_removal_p_values(mean_df, error_df, atlas)
# Out:
# [INFO] 2025-09-04 18:55:24,701 - neurophorm.visualization - plot_node_removal_p_values: start | mean=(3, 2) error=(3, 2)
# [INFO] 2025-09-04 18:55:36,043 - neurophorm.visualization - plot_node_removal_p_values: done
# [          A         B
#  A  1.000000  0.035293
#  B  0.035293  1.000000,
#            A         B
#  A  1.000000  0.000912
#  B  0.000912  1.000000,
#            A         B
#  A  1.000000  0.010415
#  B  0.010415  1.000000]
